# %%
# %pip install --no-cache-dir onnxruntime numpy matplotlib scikit-learn pandas torch --index-url https://download.pytorch.org/whl/cpu
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cpu
# ...
# Note: you may need to restart the kernel to use updated packages.
